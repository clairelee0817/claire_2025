# %% [raw]
# ---
# layout: post
# title: Incorporating Emojis
# permalink: /incorporatingemojis/
# ---

# %%
#!pip install emoji
from emoji import emojize 
print(emojize(":thumbs_up: Python is awesome! :grinning_face:"))
# Out:
# 👍 Python is awesome! 😀
